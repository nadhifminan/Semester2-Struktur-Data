# %%
a = [10,6,7,1,10,12,100,1,0,23,45,7,8,9]
urutanBenar = False
for i in range(len(a)-1,0,-1):
    print('jumlah iterasi-',i)
    urutanBenar = True
    for j in range(i):
        if a[j]>a[j+1]:
            a[j],a[j+1]=a[j+1],a[j]
            urutanBenar = False
        print(a)
    if urutanBenar:
        break

# %%
def bub(nums):
    for i in range (len(nums)-1):
        print('')
        temp=0
        for j in range(len(nums)-1-i) :
            if nums[j] > nums[j+1] :
                nums[j],nums[j+1] = nums[j+1],nums[j]
                temp+=1
            print(nums)
        if temp==0:
            return
a=[1,12,6,75,83,126,56,87,90]
bub(a)
# Out:
# [1, 12, 6, 75, 83, 126, 56, 87, 90]
# [1, 6, 12, 75, 83, 126, 56, 87, 90]
# [1, 6, 12, 75, 83, 126, 56, 87, 90]
# [1, 6, 12, 75, 83, 126, 56, 87, 90]
# [1, 6, 12, 75, 83, 126, 56, 87, 90]
# [1, 6, 12, 75, 83, 56, 126, 87, 90]
# [1, 6, 12, 75, 83, 56, 87, 126, 90]
# [1, 6, 12, 75, 83, 56, 87, 90, 126]
#
# [1, 6, 12, 75, 83, 56, 87, 90, 126]
# [1, 6, 12, 75, 83, 56, 87, 90, 126]
# [1, 6, 12, 75, 83, 56, 87, 90, 126]
# [1, 6, 12, 75, 83, 56, 87, 90, 126]
# [1, 6, 12, 75, 56, 83, 87, 90, 126]
# [1, 6, 12, 75, 56, 83, 87, 90, 126]
# [1, 6, 12, 75, 56, 83, 87, 90, 126]
#
# [1, 6, 12, 75, 56, 83, 87, 90, 126]
# [1, 6, 12, 75, 56, 83, 87, 90, 126]
# [1, 6, 12, 75, 56, 83, 87, 90, 126]
# [1, 6, 12, 56, 75, 83, 87, 90, 126]
# [1, 6, 12, 56, 75, 83, 87, 90, 126]
# [1, 6, 12, 56, 75, 83, 87, 90, 126]
#
# [1, 6, 12, 56, 75, 83, 87, 90, 126]
# [1, 6, 12, 56, 75, 83, 87, 90, 126]
# [1, 6, 12, 56, 75, 83, 87, 90, 126]
# [1, 6, 12, 56, 75, 83, 87, 90, 126]
# [1, 6, 12, 56, 75, 83, 87, 90, 126]

# %%
def bubbleSort(dataList):
    jumlah=len(dataList)
    temp=1
    for i in range(jumlah-1):
        print(f'Outer Loop #{temp}')
        temp+=1
        for j in range(jumlah-1,i,-1):
            cek=False
            if dataList[j]<dataList[j-1]:
                ubah=dataList[j]
                dataList[j]=dataList[j-1]
                dataList[j-1]=ubah
                cek=True
            print(f"is data [{j}]>data[{j-1}]?"," "*(5-len(str(cek))),f'{cek}, Data : {dataList}')
            print('|'," "*(5-len(str(cek))),'|')
    print('Sorted Data ',dataList)
a=[10,9,1,3,8,7,11]
bubbleSort(a)
# Out:
# Outer Loop #1
# is data [6]>data[5]?  False, Data : [10, 9, 1, 3, 8, 7, 11]
# |  |
# is data [5]>data[4]?   True, Data : [10, 9, 1, 3, 7, 8, 11]
# |   |
# is data [4]>data[3]?  False, Data : [10, 9, 1, 3, 7, 8, 11]
# |  |
# is data [3]>data[2]?  False, Data : [10, 9, 1, 3, 7, 8, 11]
# |  |
# is data [2]>data[1]?   True, Data : [10, 1, 9, 3, 7, 8, 11]
# |   |
# is data [1]>data[0]?   True, Data : [1, 10, 9, 3, 7, 8, 11]
# |   |
# Outer Loop #2
# is data [6]>data[5]?  False, Data : [1, 10, 9, 3, 7, 8, 11]
# |  |
# is data [5]>data[4]?  False, Data : [1, 10, 9, 3, 7, 8, 11]
# |  |
# is data [4]>data[3]?  False, Data : [1, 10, 9, 3, 7, 8, 11]
# |  |
# is data [3]>data[2]?   True, Data : [1, 10, 3, 9, 7, 8, 11]
# |   |
# is data [2]>data[1]?   True, Data : [1, 3, 10, 9, 7, 8, 11]
# |   |
# Outer Loop #3
# is data [6]>data[5]?  False, Data : [1, 3, 10, 9, 7, 8, 11]
# |  |
# is data [5]>data[4]?  False, Data : [1, 3, 10, 9, 7, 8, 11]
# |  |
# ...

# %%
def bub(data):
    for i in range(len(data)-1,-1,-1):
        for j in range(i):
            if data[j]>data[j+1]:
                data[j],data[j+1]=data[j+1],data[j]
            print(data)
a=[10,2,5,8,1,20,2,2,4]
bub(a)
# Out:
# [2, 10, 5, 8, 1, 20, 2, 2, 4]
# [2, 5, 10, 8, 1, 20, 2, 2, 4]
# [2, 5, 8, 10, 1, 20, 2, 2, 4]
# [2, 5, 8, 1, 10, 20, 2, 2, 4]
# [2, 5, 8, 1, 10, 20, 2, 2, 4]
# [2, 5, 8, 1, 10, 2, 20, 2, 4]
# [2, 5, 8, 1, 10, 2, 2, 20, 4]
# [2, 5, 8, 1, 10, 2, 2, 4, 20]
# [2, 5, 8, 1, 10, 2, 2, 4, 20]
# [2, 5, 8, 1, 10, 2, 2, 4, 20]
# [2, 5, 1, 8, 10, 2, 2, 4, 20]
# [2, 5, 1, 8, 10, 2, 2, 4, 20]
# [2, 5, 1, 8, 2, 10, 2, 4, 20]
# [2, 5, 1, 8, 2, 2, 10, 4, 20]
# [2, 5, 1, 8, 2, 2, 4, 10, 20]
# [2, 5, 1, 8, 2, 2, 4, 10, 20]
# [2, 1, 5, 8, 2, 2, 4, 10, 20]
# [2, 1, 5, 8, 2, 2, 4, 10, 20]
# [2, 1, 5, 2, 8, 2, 4, 10, 20]
# [2, 1, 5, 2, 2, 8, 4, 10, 20]
# [2, 1, 5, 2, 2, 4, 8, 10, 20]
# [1, 2, 5, 2, 2, 4, 8, 10, 20]
# [1, 2, 5, 2, 2, 4, 8, 10, 20]
# [1, 2, 2, 5, 2, 4, 8, 10, 20]
# [1, 2, 2, 2, 5, 4, 8, 10, 20]
# [1, 2, 2, 2, 4, 5, 8, 10, 20]
# [1, 2, 2, 2, 4, 5, 8, 10, 20]
# [1, 2, 2, 2, 4, 5, 8, 10, 20]
# [1, 2, 2, 2, 4, 5, 8, 10, 20]
# [1, 2, 2, 2, 4, 5, 8, 10, 20]
# [1, 2, 2, 2, 4, 5, 8, 10, 20]
# ...

# %%
def bubbleSort(listData):
    print('Data yang akan diurutkan : ', listData)
    count=0
    
    for outIter in range(len(listData)-1,-1,-1):
        count=count+1
        print ('Iterasi ke-', count,':')
        temp=0
        for i in range(outIter):
            if listData[i]>listData[i+1]:
                temp=listData[i]
                listData[i]=listData[i+1]
                listData[i+1]=temp
                temp+=1
            print(outIter,'=',listData)
        if temp==0:
            break
    print('Data urut-',listData)
a=[10,2,5,8,1,20,2,2,4]
bubbleSort(a)
# Out:
# Data yang akan diurutkan :  [10, 2, 5, 8, 1, 20, 2, 2, 4]
# Iterasi ke- 1 :
# 8 = [2, 10, 5, 8, 1, 20, 2, 2, 4]
# 8 = [2, 5, 10, 8, 1, 20, 2, 2, 4]
# 8 = [2, 5, 8, 10, 1, 20, 2, 2, 4]
# 8 = [2, 5, 8, 1, 10, 20, 2, 2, 4]
# 8 = [2, 5, 8, 1, 10, 20, 2, 2, 4]
# 8 = [2, 5, 8, 1, 10, 2, 20, 2, 4]
# 8 = [2, 5, 8, 1, 10, 2, 2, 20, 4]
# 8 = [2, 5, 8, 1, 10, 2, 2, 4, 20]
# Iterasi ke- 2 :
# 7 = [2, 5, 8, 1, 10, 2, 2, 4, 20]
# 7 = [2, 5, 8, 1, 10, 2, 2, 4, 20]
# 7 = [2, 5, 1, 8, 10, 2, 2, 4, 20]
# 7 = [2, 5, 1, 8, 10, 2, 2, 4, 20]
# 7 = [2, 5, 1, 8, 2, 10, 2, 4, 20]
# 7 = [2, 5, 1, 8, 2, 2, 10, 4, 20]
# 7 = [2, 5, 1, 8, 2, 2, 4, 10, 20]
# Iterasi ke- 3 :
# 6 = [2, 5, 1, 8, 2, 2, 4, 10, 20]
# 6 = [2, 1, 5, 8, 2, 2, 4, 10, 20]
# 6 = [2, 1, 5, 8, 2, 2, 4, 10, 20]
# 6 = [2, 1, 5, 2, 8, 2, 4, 10, 20]
# 6 = [2, 1, 5, 2, 2, 8, 4, 10, 20]
# 6 = [2, 1, 5, 2, 2, 4, 8, 10, 20]
# Iterasi ke- 4 :
# 5 = [1, 2, 5, 2, 2, 4, 8, 10, 20]
# 5 = [1, 2, 5, 2, 2, 4, 8, 10, 20]
# 5 = [1, 2, 2, 5, 2, 4, 8, 10, 20]
# ...

# %%
0%4
# Out:
# 0

# %%
a=[12,0,5,1,11,20,4,2]
bubbleSort(a)
b=[12,11,5,1,0]
print('--')
bubbleSort(b)
# Out:
# Data yang akan diurutkan :  [12, 0, 5, 1, 11, 20, 4, 2]
# outIter= 7
# Iterasi ke- 1 :
# 7 = [0, 12, 5, 1, 11, 20, 4, 2]
# 7 = [0, 5, 12, 1, 11, 20, 4, 2]
# 7 = [0, 5, 1, 12, 11, 20, 4, 2]
# 7 = [0, 5, 1, 11, 12, 20, 4, 2]
# 7 = [0, 5, 1, 11, 12, 20, 4, 2]
# 7 = [0, 5, 1, 11, 12, 4, 20, 2]
# 7 = [0, 5, 1, 11, 12, 4, 2, 20]
# outIter= 6
# Iterasi ke- 2 :
# 6 = [0, 5, 1, 11, 12, 4, 2, 20]
# 6 = [0, 1, 5, 11, 12, 4, 2, 20]
# 6 = [0, 1, 5, 11, 12, 4, 2, 20]
# 6 = [0, 1, 5, 11, 12, 4, 2, 20]
# 6 = [0, 1, 5, 11, 4, 12, 2, 20]
# 6 = [0, 1, 5, 11, 4, 2, 12, 20]
# outIter= 5
# Iterasi ke- 3 :
# 5 = [0, 1, 5, 11, 4, 2, 12, 20]
# 5 = [0, 1, 5, 11, 4, 2, 12, 20]
# 5 = [0, 1, 5, 11, 4, 2, 12, 20]
# 5 = [0, 1, 5, 4, 11, 2, 12, 20]
# 5 = [0, 1, 5, 4, 2, 11, 12, 20]
# outIter= 4
# Iterasi ke- 4 :
# 4 = [0, 1, 5, 4, 2, 11, 12, 20]
# 4 = [0, 1, 5, 4, 2, 11, 12, 20]
# 4 = [0, 1, 4, 5, 2, 11, 12, 20]
# 4 = [0, 1, 4, 2, 5, 11, 12, 20]
# outIter= 3
# Iterasi ke- 5 :
# 3 = [0, 1, 4, 2, 5, 11, 12, 20]
# ...

# %%
b=[11,12,1,5,0]
bubbleSort(b)
# Out:
# Data yang akan diurutkan :  [11, 12, 1, 5, 0]
# outIter= 4
# Iterasi ke- 1 :
# 4 = [11, 12, 1, 5, 0]
# 4 = [11, 1, 12, 5, 0]
# 4 = [11, 1, 5, 12, 0]
# 4 = [11, 1, 5, 0, 12]
# outIter= 3
# Iterasi ke- 2 :
# 3 = [1, 11, 5, 0, 12]
# 3 = [1, 5, 11, 0, 12]
# 3 = [1, 5, 0, 11, 12]
# outIter= 2
# Iterasi ke- 3 :
# 2 = [1, 5, 0, 11, 12]
# 2 = [1, 0, 5, 11, 12]
# outIter= 1
# Iterasi ke- 4 :
# 1 = [0, 1, 5, 11, 12]
# outIter= 0
# Iterasi ke- 5 :
# Data urut- [0, 1, 5, 11, 12]

# %%
b=[10,2,5,8,1,20,2,2,4]
bubbleSort(b)
# Out:
# Data yang akan diurutkan :  [10, 2, 5, 8, 1, 20, 2, 2, 4]
# outIter= 8
# Iterasi ke- 1 :
# 8 = [2, 10, 5, 8, 1, 20, 2, 2, 4]
# 8 = [2, 5, 10, 8, 1, 20, 2, 2, 4]
# 8 = [2, 5, 8, 10, 1, 20, 2, 2, 4]
# 8 = [2, 5, 8, 1, 10, 20, 2, 2, 4]
# 8 = [2, 5, 8, 1, 10, 20, 2, 2, 4]
# 8 = [2, 5, 8, 1, 10, 2, 20, 2, 4]
# 8 = [2, 5, 8, 1, 10, 2, 2, 20, 4]
# 8 = [2, 5, 8, 1, 10, 2, 2, 4, 20]
# outIter= 7
# Iterasi ke- 2 :
# 7 = [2, 5, 8, 1, 10, 2, 2, 4, 20]
# 7 = [2, 5, 8, 1, 10, 2, 2, 4, 20]
# 7 = [2, 5, 1, 8, 10, 2, 2, 4, 20]
# 7 = [2, 5, 1, 8, 10, 2, 2, 4, 20]
# 7 = [2, 5, 1, 8, 2, 10, 2, 4, 20]
# 7 = [2, 5, 1, 8, 2, 2, 10, 4, 20]
# 7 = [2, 5, 1, 8, 2, 2, 4, 10, 20]
# outIter= 6
# Iterasi ke- 3 :
# 6 = [2, 5, 1, 8, 2, 2, 4, 10, 20]
# 6 = [2, 1, 5, 8, 2, 2, 4, 10, 20]
# 6 = [2, 1, 5, 8, 2, 2, 4, 10, 20]
# 6 = [2, 1, 5, 2, 8, 2, 4, 10, 20]
# 6 = [2, 1, 5, 2, 2, 8, 4, 10, 20]
# 6 = [2, 1, 5, 2, 2, 4, 8, 10, 20]
# outIter= 5
# Iterasi ke- 4 :
# 5 = [1, 2, 5, 2, 2, 4, 8, 10, 20]
# ...

# %% [markdown]
# # materi video buble sorting

# %%
n=5
for i in range(n-1):
    print('iterasi-',i)
# Out:
# iterasi- 0
# iterasi- 1
# iterasi- 2
# iterasi- 3

# %%
n=5
for i in range(n-1,0,-1):
    print('iterasi-',i)
# Out:
# iterasi- 4
# iterasi- 3
# iterasi- 2
# iterasi- 1

# %%
n=5
for i in range(n-1,0,-1):#awal akhhir interval
    print('jumlah iterasi-',i)
    for j in range(i):
        print(j,j+1)
# Out:
# jumlah iterasi- 4
# 0 1
# 1 2
# 2 3
# 3 4
# jumlah iterasi- 3
# 0 1
# 1 2
# 2 3
# jumlah iterasi- 2
# 0 1
# 1 2
# jumlah iterasi- 1
# 0 1

# %%
n=4
a=[4,6,1]
for i in range(len(a)-1,0,-1):
    print('jumlah iterasi-',i)
    for j in range(i):
        if a[j]>a[j+1]:
            a[j],a[j+1]=a[j+1],a[j]
        print(a)
# Out:
# jumlah iterasi- 2
# [4, 6, 1]
# [4, 1, 6]
# jumlah iterasi- 1
# [1, 4, 6]

# %%
data=[10,1,15,7,3]
print(data)
counter=1
for j in range(len(data)-1):
    if data[j]>data[j+1]:
        temp=data[j]
        data[j]=data[j+1]
        data[j+1]=temp
    print(counter,'--->',data)
    counter+=1
# Out:
# [10, 1, 15, 7, 3]
# 1 ---> [1, 10, 15, 7, 3]
# 2 ---> [1, 10, 15, 7, 3]
# 3 ---> [1, 10, 7, 15, 3]
# 4 ---> [1, 10, 7, 3, 15]

# %%
data=[10,1,15,7,3]
print(data)
counter=1
for j in range(len(data)-2):
    if data[j]>data[j+1]:
        temp=data[j]
        data[j]=data[j+1]
        data[j+1]=temp
    print(counter,'--->',data)
    counter+=1
# Out:
# [10, 1, 15, 7, 3]
# 1 ---> [1, 10, 15, 7, 3]
# 2 ---> [1, 10, 15, 7, 3]
# 3 ---> [1, 10, 7, 15, 3]

# %%
data=[10,1,15,7,3]
print(data)
counter=1
for j in range(len(data)-3):
    if data[j]>data[j+1]:
        temp=data[j]
        data[j]=data[j+1]
        data[j+1]=temp
    print(counter,'--->',data)
    counter+=1
# Out:
# [10, 1, 15, 7, 3]
# 1 ---> [1, 10, 15, 7, 3]
# 2 ---> [1, 10, 15, 7, 3]

# %%
data=[10,1,15,7,3]
print(data)
counter=1
for j in range(len(data)-4):
    if data[j]>data[j+1]:
        temp=data[j]
        data[j]=data[j+1]
        data[j+1]=temp
    print(counter,'--->',data)
    counter+=1
# Out:
# [10, 1, 15, 7, 3]
# 1 ---> [1, 10, 15, 7, 3]

# %%
n=4
a=[10,6,7,1,10,12,100,1,0,23,45,7,8,9]
for i in range(len(a)-1,0,-1):
    print('jumlah iterasi-',i)
    for j in range(i):
        if a[j]>a[j+1]:
            a[j],a[j+1]=a[j+1],a[j]
        print(a)
# Out:
# jumlah iterasi- 13
# [6, 10, 7, 1, 10, 12, 100, 1, 0, 23, 45, 7, 8, 9]
# [6, 7, 10, 1, 10, 12, 100, 1, 0, 23, 45, 7, 8, 9]
# [6, 7, 1, 10, 10, 12, 100, 1, 0, 23, 45, 7, 8, 9]
# [6, 7, 1, 10, 10, 12, 100, 1, 0, 23, 45, 7, 8, 9]
# [6, 7, 1, 10, 10, 12, 100, 1, 0, 23, 45, 7, 8, 9]
# [6, 7, 1, 10, 10, 12, 100, 1, 0, 23, 45, 7, 8, 9]
# [6, 7, 1, 10, 10, 12, 1, 100, 0, 23, 45, 7, 8, 9]
# [6, 7, 1, 10, 10, 12, 1, 0, 100, 23, 45, 7, 8, 9]
# [6, 7, 1, 10, 10, 12, 1, 0, 23, 100, 45, 7, 8, 9]
# [6, 7, 1, 10, 10, 12, 1, 0, 23, 45, 100, 7, 8, 9]
# [6, 7, 1, 10, 10, 12, 1, 0, 23, 45, 7, 100, 8, 9]
# [6, 7, 1, 10, 10, 12, 1, 0, 23, 45, 7, 8, 100, 9]
# [6, 7, 1, 10, 10, 12, 1, 0, 23, 45, 7, 8, 9, 100]
# jumlah iterasi- 12
# [6, 7, 1, 10, 10, 12, 1, 0, 23, 45, 7, 8, 9, 100]
# [6, 1, 7, 10, 10, 12, 1, 0, 23, 45, 7, 8, 9, 100]
# [6, 1, 7, 10, 10, 12, 1, 0, 23, 45, 7, 8, 9, 100]
# [6, 1, 7, 10, 10, 12, 1, 0, 23, 45, 7, 8, 9, 100]
# [6, 1, 7, 10, 10, 12, 1, 0, 23, 45, 7, 8, 9, 100]
# ...

# %%
#modifikasi sehingga ketika sudah tidak ada perubahan data maka iner lub berhenti

# %%
a = [10,6,7,1,10,12,100,1,0,23,45,7,8,9]
urutanBenar = False
for i in range(len(a)-1,0,-1):
    print('jumlah iterasi-',i)
    urutanBenar = True
    for j in range(i):
        if a[j]>a[j+1]:
            a[j],a[j+1]=a[j+1],a[j]
            urutanBenar = False
        print(a)
    if urutanBenar:
        break
# Out:
# jumlah iterasi- 13
# [6, 10, 7, 1, 10, 12, 100, 1, 0, 23, 45, 7, 8, 9]
# [6, 7, 10, 1, 10, 12, 100, 1, 0, 23, 45, 7, 8, 9]
# [6, 7, 1, 10, 10, 12, 100, 1, 0, 23, 45, 7, 8, 9]
# [6, 7, 1, 10, 10, 12, 100, 1, 0, 23, 45, 7, 8, 9]
# [6, 7, 1, 10, 10, 12, 100, 1, 0, 23, 45, 7, 8, 9]
# [6, 7, 1, 10, 10, 12, 100, 1, 0, 23, 45, 7, 8, 9]
# [6, 7, 1, 10, 10, 12, 1, 100, 0, 23, 45, 7, 8, 9]
# [6, 7, 1, 10, 10, 12, 1, 0, 100, 23, 45, 7, 8, 9]
# [6, 7, 1, 10, 10, 12, 1, 0, 23, 100, 45, 7, 8, 9]
# [6, 7, 1, 10, 10, 12, 1, 0, 23, 45, 100, 7, 8, 9]
# [6, 7, 1, 10, 10, 12, 1, 0, 23, 45, 7, 100, 8, 9]
# [6, 7, 1, 10, 10, 12, 1, 0, 23, 45, 7, 8, 100, 9]
# [6, 7, 1, 10, 10, 12, 1, 0, 23, 45, 7, 8, 9, 100]
# jumlah iterasi- 12
# [6, 7, 1, 10, 10, 12, 1, 0, 23, 45, 7, 8, 9, 100]
# [6, 1, 7, 10, 10, 12, 1, 0, 23, 45, 7, 8, 9, 100]
# [6, 1, 7, 10, 10, 12, 1, 0, 23, 45, 7, 8, 9, 100]
# [6, 1, 7, 10, 10, 12, 1, 0, 23, 45, 7, 8, 9, 100]
# [6, 1, 7, 10, 10, 12, 1, 0, 23, 45, 7, 8, 9, 100]
# ...

# %%
def bidirectionalBubbleSort(listData):
    print('Data yang akan diurutkan : ', listData)
    count = 0
    left = 0
    right = len(listData) - 1
    while left < right:
        count += 1
        print('Iterasi ke-', count, ':')
        for i in range(left, right):
            if listData[i] > listData[i+1]:
                listData[i], listData[i+1] = listData[i+1], listData[i]
        print('Kiri-kanan=', listData)

        right -= 1
        for i in range(right, left, -1):
            if listData[i] < listData[i-1]:
                listData[i], listData[i-1] = listData[i-1], listData[i]
        print('Kanan-kiri=', listData)

        left += 1

    return('Data urut-', listData)
a = [10,6,7,1,10,12,100,1,0,23,45,7,8,9]
print(bidirectionalBubbleSort(a))
# Out:
# Data yang akan diurutkan :  [10, 6, 7, 1, 10, 12, 100, 1, 0, 23, 45, 7, 8, 9]
# Iterasi ke- 1 :
# Kiri-kanan= [6, 7, 1, 10, 10, 12, 1, 0, 23, 45, 7, 8, 9, 100]
# Kanan-kiri= [0, 6, 7, 1, 10, 10, 12, 1, 7, 23, 45, 8, 9, 100]
# Iterasi ke- 2 :
# Kiri-kanan= [0, 6, 1, 7, 10, 10, 1, 7, 12, 23, 8, 9, 45, 100]
# Kanan-kiri= [0, 1, 6, 1, 7, 10, 10, 7, 8, 12, 23, 9, 45, 100]
# Iterasi ke- 3 :
# Kiri-kanan= [0, 1, 1, 6, 7, 10, 7, 8, 10, 12, 9, 23, 45, 100]
# Kanan-kiri= [0, 1, 1, 6, 7, 7, 10, 8, 9, 10, 12, 23, 45, 100]
# Iterasi ke- 4 :
# Kiri-kanan= [0, 1, 1, 6, 7, 7, 8, 9, 10, 10, 12, 23, 45, 100]
# Kanan-kiri= [0, 1, 1, 6, 7, 7, 8, 9, 10, 10, 12, 23, 45, 100]
# Iterasi ke- 5 :
# Kiri-kanan= [0, 1, 1, 6, 7, 7, 8, 9, 10, 10, 12, 23, 45, 100]
# Kanan-kiri= [0, 1, 1, 6, 7, 7, 8, 9, 10, 10, 12, 23, 45, 100]
# Iterasi ke- 6 :
# Kiri-kanan= [0, 1, 1, 6, 7, 7, 8, 9, 10, 10, 12, 23, 45, 100]
# Kanan-kiri= [0, 1, 1, 6, 7, 7, 8, 9, 10, 10, 12, 23, 45, 100]
# Iterasi ke- 7 :
# ...

# %%
def bidirectionalBubbleSort(listData):
    print('Data yang akan diurutkan : ', listData)
    count = 0
    left = 0
    right = len(listData) - 1
    while left < right:
        count += 1
        print('Iterasi ke-', count, ':')
        for i in range(left, right):
            if listData[i] > listData[i+1]:
                listData[i], listData[i+1] = listData[i+1], listData[i]
        print('Kiri-kanan=', listData)

        right -= 1
    return('Data urut-', listData)
a = [10,6,7,1,10,12,100,1,0,23,45,7,8,9]
print(bidirectionalBubbleSort(a))
# Out:
# Data yang akan diurutkan :  [10, 6, 7, 1, 10, 12, 100, 1, 0, 23, 45, 7, 8, 9]
# Iterasi ke- 1 :
# Kiri-kanan= [6, 7, 1, 10, 10, 12, 1, 0, 23, 45, 7, 8, 9, 100]
# Iterasi ke- 2 :
# Kiri-kanan= [6, 1, 7, 10, 10, 1, 0, 12, 23, 7, 8, 9, 45, 100]
# Iterasi ke- 3 :
# Kiri-kanan= [1, 6, 7, 10, 1, 0, 10, 12, 7, 8, 9, 23, 45, 100]
# Iterasi ke- 4 :
# Kiri-kanan= [1, 6, 7, 1, 0, 10, 10, 7, 8, 9, 12, 23, 45, 100]
# Iterasi ke- 5 :
# Kiri-kanan= [1, 6, 1, 0, 7, 10, 7, 8, 9, 10, 12, 23, 45, 100]
# Iterasi ke- 6 :
# Kiri-kanan= [1, 1, 0, 6, 7, 7, 8, 9, 10, 10, 12, 23, 45, 100]
# Iterasi ke- 7 :
# Kiri-kanan= [1, 0, 1, 6, 7, 7, 8, 9, 10, 10, 12, 23, 45, 100]
# Iterasi ke- 8 :
# Kiri-kanan= [0, 1, 1, 6, 7, 7, 8, 9, 10, 10, 12, 23, 45, 100]
# Iterasi ke- 9 :
# Kiri-kanan= [0, 1, 1, 6, 7, 7, 8, 9, 10, 10, 12, 23, 45, 100]
# Iterasi ke- 10 :
# Kiri-kanan= [0, 1, 1, 6, 7, 7, 8, 9, 10, 10, 12, 23, 45, 100]
# Iterasi ke- 11 :
# Kiri-kanan= [0, 1, 1, 6, 7, 7, 8, 9, 10, 10, 12, 23, 45, 100]
# ...

# %%
a=[10,1,15,7,3]
for i in range(len(a)-1,0,-1):
    print('jumlah iterasi-',i)
    for j in range(i):
        if a[j]>a[j+1]:
            a[j],a[j+1]=a[j+1],a[j]
        print(a)
# Out:
# jumlah iterasi- 4
# [1, 10, 15, 7, 3]
# [1, 10, 15, 7, 3]
# [1, 10, 7, 15, 3]
# [1, 10, 7, 3, 15]
# jumlah iterasi- 3
# [1, 10, 7, 3, 15]
# [1, 7, 10, 3, 15]
# [1, 7, 3, 10, 15]
# jumlah iterasi- 2
# [1, 7, 3, 10, 15]
# [1, 3, 7, 10, 15]
# jumlah iterasi- 1
# [1, 3, 7, 10, 15]

# %% [markdown]
# # selection sort

# %%
def selectionSort(listData):
    print('Algoritma Selection Sort konvensional')
    print('Data Awal=',listData)
    for outIter in range(len(listData)-1):
        minIndex=outIter
        for i in range(outIter+1,len(listData)):
            if listData[i]<listData[minIndex]:
                minIndex=i
        temp=listData[outIter]
        listData[outIter]=listData[minIndex]
        listData[minIndex]=temp
        print('Iterasi ke-',outIter+1,':',listData)
    print('Data Urut=',listData)

# %%
a=[10,1,15,7,3]
selectionSort(a)
# Out:
# Algoritma Selection Sort konvensional
# Data Awal= [10, 1, 15, 7, 3]
# Iterasi ke- 1 : [1, 10, 15, 7, 3]
# Iterasi ke- 2 : [1, 3, 15, 7, 10]
# Iterasi ke- 3 : [1, 3, 7, 15, 10]
# Iterasi ke- 4 : [1, 3, 7, 10, 15]
# Data Urut= [1, 3, 7, 10, 15]

# %%
a[0],a[-1]
# Out:
# (1, 15)

# %%
a=[10,1,15,7,3]
print(data)
nilaiMin=data[indeks]
start=0
for i in range(1,len(data)):
    if data[i]<nilaiMin:
        nilaiMin=data[i]
        indeks=i
print(nilaiMin)
data[start]=data[start]
data[start]=nilaiMin
print(data)
# Out:
# [1, 10, 1, 7, 3]
# 1
# [1, 10, 1, 7, 3]

# %%
for i in range()

# %%
a=[10,1,15,7,3]
print(data)
nilaiMin=data[0]
indeks=2
for i in range(1,len(data)):
    if data[i]<nilaiMin:
        nilaiMin=data[i]
        indeks=i
print(nilaiMin)
data[indeks]=data[2]
data[2]=nilaiMin
print(data)
# Out:
# [1, 10, 15, 7, 3]
# 1
# [1, 10, 1, 7, 3]

# %%
for start in range(len(data)-1):
    for i in range(start+1,len(data)):
        if data[i]<nilaiMin:
            nilaiMin=data[i]
            indeks=i
    print('nilai minimum',nilaiMin,'indeks',indeks)
    data[indeks]=data[i]
    data[start]=nilaiMin
    print('data urut--->',data)
    print()
# Out:
# nilai minimum 1 indeks 2
# data urut---> [1, 10, 3, 7, 3]
#
# nilai minimum 1 indeks 2
# data urut---> [1, 1, 3, 7, 3]
#
# nilai minimum 1 indeks 2
# data urut---> [1, 1, 1, 7, 3]
#
# nilai minimum 1 indeks 2
# data urut---> [1, 1, 3, 1, 3]

# %%
data=[10,3,9,1,2]
for outerLoop in range(len(data)-1):
    minFlag=outerLoop
    for j in range(outerLoop+1,len(data)):
        if data[minFlag]>data[j]:
            minFlag=j
    data[outerLoop],data[minFlag]=data[minFlag],data[outerLoop]
    print(data)
# Out:
# [1, 3, 9, 10, 2]
# [1, 2, 9, 10, 3]
# [1, 2, 3, 10, 9]
# [1, 2, 3, 9, 10]

# %%
def sort_data(data, maksimum):
    if maksimum > len(data):
        maksimum = len(data)
    for outerLoop in range(maksimum-1):
        maxFlag = outerLoop
        for j in range(outerLoop+1, maksimum):
            if data[maxFlag] < data[j]:
                maxFlag = j
        data[outerLoop], data[maxFlag] = data[maxFlag], data[outerLoop]
    return data
print(sort_data(lis,))

# %%
def sort_data(data, maks):
    if maks > len(data):
        maks = len(data)
    for outerLoop in range(len(data)-1, len(data)-maks-1, -1):
        maxFlag = outerLoop
        for j in range(outerLoop-1, -1, -1):
            if data[maxFlag] < data[j]:
                maxFlag = j
        data[outerLoop], data[maxFlag] = data[maxFlag], data[outerLoop]
    return data
data = [10, 3, 9, 1, 2]
sorted_data = sort_data(data,4)
print(sorted_data) # Output: [10, 9, 3, 2, 1]
# Out:
# [1, 2, 3, 9, 10]

# %% [markdown]
# # pertemuan 9

# %%
data=[4,7,1,8,15]
print(data)
data[2]=data[1]
print(data)
data[1]=data[0]
print(data)
data[0]=1
print(data)
# Out:
# [4, 7, 1, 8, 15]
# [4, 7, 7, 8, 15]
# [4, 4, 7, 8, 15]
# [1, 4, 7, 8, 15]

# %%
data=[7,4,1,8,15]
for i in range(len(data)-1):
    ind=i+1
    flag=data[i+1]
    print('indeks flag= ',ind)
    for j in range(ind-1,-1,-1):
        print('perbandingan indeks :',ind,j)
# Out:
# indeks flag=  1
# perbandingan indeks : 1 0
# indeks flag=  2
# perbandingan indeks : 2 1
# perbandingan indeks : 2 0
# indeks flag=  3
# perbandingan indeks : 3 2
# perbandingan indeks : 3 1
# perbandingan indeks : 3 0
# indeks flag=  4
# perbandingan indeks : 4 3
# perbandingan indeks : 4 2
# perbandingan indeks : 4 1
# perbandingan indeks : 4 0

# %%
data=[7,4,1,8,15]
for i in range(len(data)-1):
    ind=i+1
    flag=data[ind]
    print('[',ind,']:',flag)
    temp=ind-1
    while temp !=-1:
        print('perbandingan indeks:',ind,temp)
        temp-=1
# Out:
# [ 1 ]: 4
# perbandingan indeks: 1 0
# [ 2 ]: 1
# perbandingan indeks: 2 1
# perbandingan indeks: 2 0
# [ 3 ]: 8
# perbandingan indeks: 3 2
# perbandingan indeks: 3 1
# perbandingan indeks: 3 0
# [ 4 ]: 15
# perbandingan indeks: 4 3
# perbandingan indeks: 4 2
# perbandingan indeks: 4 1
# perbandingan indeks: 4 0

# %%
data=[7,4,1,8,6,15,9,3,2]
for i in range(len(data)-1):
    ind=i+1
    flag=data[ind]
    print('[',ind,']:',flag)
    temp=ind-1
    while temp !=-1 and data[temp]>flag:
#         print('perbandingan indeks:',ind,temp)
        data[temp+1]=data[temp]
        temp-=1
        print('hasil inner Lopp :',data)
    data[temp+1]=flag
    print('hasil sementara : ',data)
print('data urut :',data)
# Out:
# [ 1 ]: 4
# hasil inner Lopp : [7, 7, 1, 8, 6, 15, 9, 3, 2]
# hasil sementara :  [4, 7, 1, 8, 6, 15, 9, 3, 2]
# [ 2 ]: 1
# hasil inner Lopp : [4, 7, 7, 8, 6, 15, 9, 3, 2]
# hasil inner Lopp : [4, 4, 7, 8, 6, 15, 9, 3, 2]
# hasil sementara :  [1, 4, 7, 8, 6, 15, 9, 3, 2]
# [ 3 ]: 8
# hasil sementara :  [1, 4, 7, 8, 6, 15, 9, 3, 2]
# [ 4 ]: 6
# hasil inner Lopp : [1, 4, 7, 8, 8, 15, 9, 3, 2]
# hasil inner Lopp : [1, 4, 7, 7, 8, 15, 9, 3, 2]
# hasil sementara :  [1, 4, 6, 7, 8, 15, 9, 3, 2]
# [ 5 ]: 15
# hasil sementara :  [1, 4, 6, 7, 8, 15, 9, 3, 2]
# [ 6 ]: 9
# hasil inner Lopp : [1, 4, 6, 7, 8, 15, 15, 3, 2]
# hasil sementara :  [1, 4, 6, 7, 8, 9, 15, 3, 2]
# [ 7 ]: 3
# hasil inner Lopp : [1, 4, 6, 7, 8, 9, 15, 15, 2]
# hasil inner Lopp : [1, 4, 6, 7, 8, 9, 9, 15, 2]
# hasil inner Lopp : [1, 4, 6, 7, 8, 8, 9, 15, 2]
# hasil inner Lopp : [1, 4, 6, 7, 7, 8, 9, 15, 2]
# hasil inner Lopp : [1, 4, 6, 6, 7, 8, 9, 15, 2]
# hasil inner Lopp : [1, 4, 4, 6, 7, 8, 9, 15, 2]
# ...

# %%
# coba disispkan disebelah kanannya

# %% [markdown]
# # insertion sort

# %%
a=[10,5,7,9]
for i in range(1,len(a)):
    key=a[i]
#     print(key)
    j=i-1
    while j>=0 and key <= a[j]:
        #print('j',j)
        a[j+1]=a[j]
        j-=1
        print(j,'=',a)
    a[j+1]=key#insert key nya
    print(a)
# Out:
# -1 = [10, 10, 7, 9]
# [5, 10, 7, 9]
# 0 = [5, 10, 10, 9]
# [5, 7, 10, 9]
# 1 = [5, 7, 10, 10]
# [5, 7, 9, 10]

# %% [markdown]
# # pertemuan 20 maret 2023

# %%
#ascending -selection sort
data=[7,2,1,5,4,12,0]
maksData=data[0]#
idMaks=0
for i in range(1,len(data)):
    print(maksData,'<',data[i])
    if maksData<data[i]:
        maksData=data[i]
        idMaks=i
print('maksimal = ',maksData,'indeks =',idMaks)

data[idMaks]=data[len(data)-1]
data[len(data)-1]=maksData
print('data sort temp = ',data)
# Out:
# 7 < 2
# 7 < 1
# 7 < 5
# 7 < 4
# 7 < 12
# 12 < 0
# maksimal =  12 indeks = 5
# data sort temp =  [7, 2, 1, 5, 4, 0, 12]

# %%
print('data sort temp = ',data)
# data=[7,2,1,5,4,12,0]
maksData=data[0]#
idMaks=0
for i in range(1,len(data)-1):
    print(maksData,'<',data[i])
    if maksData<data[i]:
        maksData=data[i]
        idMaks=i
print('maksimal = ',maksData,'indeks =',idMaks)

data[idMaks]=data[len(data)-2]
data[len(data)-2]=maksData
print('data sort temp = ',data)
# Out:
# data sort temp =  [7, 2, 1, 5, 4, 0, 12]
# 7 < 2
# 7 < 1
# 7 < 5
# 7 < 4
# 7 < 0
# maksimal =  7 indeks = 0
# data sort temp =  [0, 2, 1, 5, 4, 7, 12]

# %%
print('data sort temp = ',data)
# data=[7,2,1,5,4,12,0]
maksData=data[0]#
idMaks=0
for i in range(1,len(data)-2):
    print(maksData,'<',data[i])
    if maksData<data[i]:
        maksData=data[i]
        idMaks=i
print('maksimal = ',maksData,'indeks =',idMaks)

data[idMaks]=data[len(data)-3]
data[len(data)-3]=maksData
print('data sort temp = ',data)
# Out:
# data sort temp =  [0, 2, 1, 5, 4, 7, 12]
# 0 < 2
# 2 < 1
# 2 < 5
# 5 < 4
# maksimal =  5 indeks = 3
# data sort temp =  [0, 2, 1, 4, 5, 7, 12]

# %%
print('data sort temp = ',data)
# data=[7,2,1,5,4,12,0]
maksData=data[0]#
idMaks=0
for i in range(1,len(data)-3):
    print(maksData,'<',data[i])
    if maksData<data[i]:
        maksData=data[i]
        idMaks=i
print('maksimal = ',maksData,'indeks =',idMaks)

data[idMaks]=data[len(data)-4]
data[len(data)-4]=maksData
print('data sort temp = ',data)
# Out:
# data sort temp =  [0, 2, 1, 4, 5, 7, 12]
# 0 < 2
# 2 < 1
# 2 < 4
# maksimal =  4 indeks = 3
# data sort temp =  [0, 2, 1, 4, 5, 7, 12]

# %%
print('data sort temp = ',data)
# data=[7,2,1,5,4,12,0]
maksData=data[0]#
idMaks=0
for i in range(1,len(data)-4):
    print(maksData,'<',data[i])
    if maksData<data[i]:
        maksData=data[i]
        idMaks=i
print('maksimal = ',maksData,'indeks =',idMaks)

data[idMaks]=data[len(data)-5]
data[len(data)-5]=maksData
print('data sort temp = ',data)
# Out:
# data sort temp =  [0, 2, 1, 4, 5, 7, 12]
# 0 < 2
# 2 < 1
# maksimal =  2 indeks = 1
# data sort temp =  [0, 1, 2, 4, 5, 7, 12]

# %%
# hasil akhir ascending -selection sort
data=[7,2,1,5,4,12,0]
maksData=data[0]#
idMaks=0
for it in range(1,len(data)-1):
    maksData=data[0]#
    idMaks=0
    for i in range(1,len(data)-it):
        print(maksData,'<',data[i])
        if maksData<data[i]:
            maksData=data[i]
            idMaks=i
    print('maksimal = ',maksData,'indeks =',idMaks)

    data[idMaks]=data[len(data)-(it+1)]
    data[len(data)-(it+1)]=maksData
    print('data sort temp = ',data)
    print('')
# Out:
# 7 < 2
# 7 < 1
# 7 < 5
# 7 < 4
# 7 < 12
# maksimal =  12 indeks = 5
# data sort temp =  [7, 2, 1, 5, 4, 12, 0]
#
# 7 < 2
# 7 < 1
# 7 < 5
# 7 < 4
# maksimal =  7 indeks = 0
# data sort temp =  [4, 2, 1, 5, 7, 12, 0]
#
# 4 < 2
# 4 < 1
# 4 < 5
# maksimal =  5 indeks = 3
# data sort temp =  [4, 2, 1, 5, 7, 12, 0]
#
# 4 < 2
# 4 < 1
# maksimal =  4 indeks = 0
# data sort temp =  [1, 2, 4, 5, 7, 12, 0]
#
# 1 < 2
# maksimal =  2 indeks = 1
# data sort temp =  [1, 2, 4, 5, 7, 12, 0]

# %%
data=[7,2,1,5,4,12,0]
idMaks=0
for it in range(1,len(data)-1):
    maksData=data[0]#
    idMaks=0
    for i in range(1,len(data)-it):
        print(maksData,'<',data[i])
        if maksData>data[i]:
            maksData=data[i]
            idMaks=i
    print('maksimal = ',maksData,'indeks =',idMaks)

    data[idMaks]=data[len(data)-(it+1)]
    data[len(data)-(it+1)]=maksData
    print('data sort temp = ',data)
    print('')
# Out:
# 7 < 2
# 2 < 1
# 1 < 5
# 1 < 4
# 1 < 12
# maksimal =  1 indeks = 2
# data sort temp =  [7, 2, 12, 5, 4, 1, 0]
#
# 7 < 2
# 2 < 12
# 2 < 5
# 2 < 4
# maksimal =  2 indeks = 1
# data sort temp =  [7, 4, 12, 5, 2, 1, 0]
#
# 7 < 4
# 4 < 12
# 4 < 5
# maksimal =  4 indeks = 1
# data sort temp =  [7, 5, 12, 4, 2, 1, 0]
#
# 7 < 5
# 5 < 12
# maksimal =  5 indeks = 1
# data sort temp =  [7, 12, 5, 4, 2, 1, 0]
#
# 7 < 12
# maksimal =  7 indeks = 0
# data sort temp =  [12, 7, 5, 4, 2, 1, 0]

# %%
data=[7,2,1,5,4,12,0]
for i in range(len(data)-1):
    minFlag=i
    for j in range(i+1,len(data)):
        if data[minFlag]>data[j]:
            minFlag=j
    data[i],data[minFlag]=data[minFlag],data[i]
    print(data)
# Out:
# [0, 2, 1, 5, 4, 12, 7]
# [0, 1, 2, 5, 4, 12, 7]
# [0, 1, 2, 5, 4, 12, 7]
# [0, 1, 2, 4, 5, 12, 7]
# [0, 1, 2, 4, 5, 12, 7]
# [0, 1, 2, 4, 5, 7, 12]

# %%
data=[7,2,1,5,4,12,0]
for outerLoop in range(len(data)-1):
    minFlag=outerLoop
    for j in range(outerLoop+1,len(data)):
        if data[minFlag]>data[j]:
            minFlag=j
    data[outerLoop],data[minFlag]=data[minFlag],data[outerLoop]
    print(data)
# Out:
# [0, 2, 1, 5, 4, 12, 7]
# [0, 1, 2, 5, 4, 12, 7]
# [0, 1, 2, 5, 4, 12, 7]
# [0, 1, 2, 4, 5, 12, 7]
# [0, 1, 2, 4, 5, 12, 7]
# [0, 1, 2, 4, 5, 7, 12]

# %%
#mau mengurutkan maksimal kanan,minimal tetep ascending minimal ada di kiri

# %%
data=[7,2,1,5,4,12]
minData=data[0]
idmin=0
for i in range(1,len(data)):
    print(minData,'>',data[i])
    if minData>data[i]:
        minData=data[1]
        idMin=i
print('minimal',minData,'indeks',idMin)
data[idMin]=data[0]
data[0]=minData
print('data=',data)
# Out:
# 7 > 2
# 2 > 1
# 2 > 5
# 2 > 4
# 2 > 12
# minimal 2 indeks 2
# data= [2, 2, 7, 5, 4, 12]

# %%
data=[7,2,1,5,4,12]
for i in range(len(data)-1):
    minData=data[i]
    idmin=i
    for i in range(i+1,len(data)):
        print(minData,'>',data[i])
        if minData>data[i]:
            minData=data[i]
            idMin=i
    print('minimal',minData,'indeks',idMin)
    data[idMin]=data[i]
    data[i]=minData
    print('data=',data)
# Out:
# 7 > 2
# 2 > 1
# 1 > 5
# 1 > 4
# 1 > 12
# minimal 1 indeks 2
# data= [7, 2, 12, 5, 4, 1]
# 2 > 12
# 2 > 5
# 2 > 4
# 2 > 1
# minimal 1 indeks 5
# data= [7, 2, 12, 5, 4, 1]
# 12 > 5
# 5 > 4
# 4 > 1
# minimal 1 indeks 5
# data= [7, 2, 12, 5, 4, 1]
# 5 > 4
# 4 > 1
# minimal 1 indeks 5
# data= [7, 2, 12, 5, 4, 1]
# 4 > 1
# minimal 1 indeks 5
# data= [7, 2, 12, 5, 4, 1]

# %%
data=[7,2,1,5,4,12,0]
print('data awal=',data)
for start in range(len(data)-1):
    print('start =',start)
    minData=data[start]
    idMin=start
    for i in range(start+1,len(data)):
        print(minData,'>',data[i])
        if minData>data[i]:
            minData=data[i]
            idMin=i
    print('data minimal =',minData,'index =',idMin)
    data[idMin]=minData
    data[start]=minData
    print('data =',data)
# Out:
# data awal= [7, 2, 1, 5, 4, 12, 0]
# start = 0
# 7 > 2
# 2 > 1
# 1 > 5
# 1 > 4
# 1 > 12
# 1 > 0
# data minimal = 0 index = 6
# data = [0, 2, 1, 5, 4, 12, 0]
# start = 1
# 2 > 1
# 1 > 5
# 1 > 4
# 1 > 12
# 1 > 0
# data minimal = 0 index = 6
# data = [0, 0, 1, 5, 4, 12, 0]
# start = 2
# 1 > 5
# 1 > 4
# 1 > 12
# 1 > 0
# data minimal = 0 index = 6
# data = [0, 0, 0, 5, 4, 12, 0]
# start = 3
# 5 > 4
# 4 > 12
# 4 > 0
# data minimal = 0 index = 6
# data = [0, 0, 0, 0, 4, 12, 0]
# start = 4
# 4 > 12
# 4 > 0
# data minimal = 0 index = 6
# data = [0, 0, 0, 0, 0, 12, 0]
# start = 5
# 12 > 0
# data minimal = 0 index = 6
# data = [0, 0, 0, 0, 0, 0, 0]

# %%
#Pr cari yanng descanding contoh maks[i]>minimal

# %%
data = [5, 4, 7, 1, 9, 2, 8, 3, 10, 6]
print(data)
for i in range(len(data)-1, 0, -1):
    f = i-1
    g = i
    fg = data[f]
    while (g <= len(data)-1 and data[g] < fg):
        data[g-1] = data[g]
        g +=1
        print(data)
    data[g-1] = fg
    print()
print(data)

# %%
data=[7,2,1,5,4,12]
for i in range(1,len(data)):
    pembanding=data[i]
    print('indeks-',i,':',pembanding)
    for j in range(i):
        print('bandingkan antara ',pembanding,'dengan',data[j])
# Out:
# indeks- 1 : 2
# bandingkan antara  2 dengan 7
# indeks- 2 : 1
# bandingkan antara  1 dengan 7
# bandingkan antara  1 dengan 2
# indeks- 3 : 5
# bandingkan antara  5 dengan 7
# bandingkan antara  5 dengan 2
# bandingkan antara  5 dengan 1
# indeks- 4 : 4
# bandingkan antara  4 dengan 7
# bandingkan antara  4 dengan 2
# bandingkan antara  4 dengan 1
# bandingkan antara  4 dengan 5
# indeks- 5 : 12
# bandingkan antara  12 dengan 7
# bandingkan antara  12 dengan 2
# bandingkan antara  12 dengan 1
# bandingkan antara  12 dengan 5
# bandingkan antara  12 dengan 4

# %%
def insertionSort(lis):
    for j in range(1,len(lis)):
        print(lis)
        key=lis[j]
        ind=j
        while (ind>0 and lis[ind-1]>key):
            lis[ind]=lis[ind-1]
            ind=ind-1
            print('inner=',lis)
        lis[ind]=key
    print('sortedData=',lis)
data=[10,2,5,8,1,20,2,2,4]
insertionSort(data)
# Out:
# [10, 2, 5, 8, 1, 20, 2, 2, 4]
# inner= [10, 10, 5, 8, 1, 20, 2, 2, 4]
# [2, 10, 5, 8, 1, 20, 2, 2, 4]
# inner= [2, 10, 10, 8, 1, 20, 2, 2, 4]
# [2, 5, 10, 8, 1, 20, 2, 2, 4]
# inner= [2, 5, 10, 10, 1, 20, 2, 2, 4]
# [2, 5, 8, 10, 1, 20, 2, 2, 4]
# inner= [2, 5, 8, 10, 10, 20, 2, 2, 4]
# inner= [2, 5, 8, 8, 10, 20, 2, 2, 4]
# inner= [2, 5, 5, 8, 10, 20, 2, 2, 4]
# inner= [2, 2, 5, 8, 10, 20, 2, 2, 4]
# [1, 2, 5, 8, 10, 20, 2, 2, 4]
# [1, 2, 5, 8, 10, 20, 2, 2, 4]
# inner= [1, 2, 5, 8, 10, 20, 20, 2, 4]
# inner= [1, 2, 5, 8, 10, 10, 20, 2, 4]
# inner= [1, 2, 5, 8, 8, 10, 20, 2, 4]
# inner= [1, 2, 5, 5, 8, 10, 20, 2, 4]
# [1, 2, 2, 5, 8, 10, 20, 2, 4]
# inner= [1, 2, 2, 5, 8, 10, 20, 20, 4]
# inner= [1, 2, 2, 5, 8, 10, 10, 20, 4]
# inner= [1, 2, 2, 5, 8, 8, 10, 20, 4]
# inner= [1, 2, 2, 5, 5, 8, 10, 20, 4]
# [1, 2, 2, 2, 5, 8, 10, 20, 4]
# inner= [1, 2, 2, 2, 5, 8, 10, 20, 20]
# inner= [1, 2, 2, 2, 5, 8, 10, 10, 20]
# inner= [1, 2, 2, 2, 5, 8, 8, 10, 20]
# ...
